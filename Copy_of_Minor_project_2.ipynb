# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
# !wget https://as2.ftcdn.net/v2/jpg/01/97/83/69/1000_F_197836949_QTkBYuzNy97g8VmBdUCs12TQLcD2Udtl.jpg -O p10.jpg
# Out:
# --2023-12-09 07:51:54--  https://as2.ftcdn.net/v2/jpg/01/97/83/69/1000_F_197836949_QTkBYuzNy97g8VmBdUCs12TQLcD2Udtl.jpg
# Resolving as2.ftcdn.net (as2.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to as2.ftcdn.net (as2.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 282879 (276K) [image/jpeg]
# Saving to: ‘p10.jpg’
#
# p10.jpg             100%[===================>] 276.25K  --.-KB/s    in 0.007s
#
# 2023-12-09 07:51:54 (38.8 MB/s) - ‘p10.jpg’ saved [282879/282879]

# %%
a=cv2.imread("/content/p10.jpg")
a
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
img=cv2.imread("/content/p10.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667>

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2023-12-09 07:54:34--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.009s
#
# 2023-12-09 07:54:34 (96.0 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
img=cv2.imread("/p10.jpg")
faces=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
f=faces.detectMultiScale(img,1.12,5)
#cv2_imshow(img)
for(x,y,w,h) in f:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667>

# %%
# !wget https://t3.ftcdn.net/jpg/06/56/01/70/360_F_656017050_HS7zv9aP1SIw1oDXm9FlyN0GfGK83XuU.jpg -O p11.jpg
# Out:
# --2023-12-09 07:58:48--  https://t3.ftcdn.net/jpg/06/56/01/70/360_F_656017050_HS7zv9aP1SIw1oDXm9FlyN0GfGK83XuU.jpg
# Resolving t3.ftcdn.net (t3.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to t3.ftcdn.net (t3.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45405 (44K) [image/jpeg]
# Saving to: ‘p11.jpg’
#
# p11.jpg             100%[===================>]  44.34K  --.-KB/s    in 0.002s
#
# 2023-12-09 07:58:48 (28.0 MB/s) - ‘p11.jpg’ saved [45405/45405]

# %%
img=cv2.imread("/p11.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=643x360>

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Out:
# --2023-12-09 08:00:43--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188506 (184K) [text/plain]
# Saving to: ‘haarcascade_smile.xml’
#
# haarcascade_smile.x 100%[===================>] 184.09K  --.-KB/s    in 0.005s
#
# 2023-12-09 08:00:43 (32.9 MB/s) - ‘haarcascade_smile.xml’ saved [188506/188506]

# %%
img=cv2.imread("/p11.jpg")
smile=cv2.CascadeClassifier("/content/haarcascade_smile.xml")
s=smile.detectMultiScale(img,1.9,6)
#cv2_imshow(img)
for(x,y,w,h) in s:
    cv2.rectangle(img,(x,y),(x+w,y+h),(128,0,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=643x360>

# %%
# !wget https://i.pinimg.com/564x/e8/d6/f9/e8d6f9e2114fdead8f1e1e69a25ab439.jpg -O p12.jpg
# Out:
# --2023-12-09 08:06:07--  https://i.pinimg.com/564x/e8/d6/f9/e8d6f9e2114fdead8f1e1e69a25ab439.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 184.28.190.51, 184.28.190.81, 2600:1408:5400:7::170c:90c3
# Connecting to i.pinimg.com (i.pinimg.com)|184.28.190.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32843 (32K) [image/jpeg]
# Saving to: ‘p12.jpg’
#
# p12.jpg             100%[===================>]  32.07K  --.-KB/s    in 0.007s
#
# 2023-12-09 08:06:07 (4.21 MB/s) - ‘p12.jpg’ saved [32843/32843]

# %%
img=cv2.imread("/p12.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=476x645>

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2023-12-09 08:07:28--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.006s
#
# 2023-12-09 08:07:28 (56.6 MB/s) - ‘haarcascade_eye.xml’ saved [341406/341406]

# %%
img=cv2.imread("/p12.jpg")
eye=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
e=eye.detectMultiScale(img,2.2,4)
#cv2_imshow(img)
for(x,y,w,h) in e:
    cv2.rectangle(img,(x,y),(x+w,y+h),(128,255,0),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=476x645>

# %%
# !wget https://previews.123rf.com/images/prometeus/prometeus1801/prometeus180100437/93394480-two-pretty-girls-in-glasses-are-posing-in-studio-over-blue-background-beauty-fashion-optics-eyewear.jpg -O p21.jpg
# Out:
# --2023-12-09 08:27:16--  https://previews.123rf.com/images/prometeus/prometeus1801/prometeus180100437/93394480-two-pretty-girls-in-glasses-are-posing-in-studio-over-blue-background-beauty-fashion-optics-eyewear.jpg
# Resolving previews.123rf.com (previews.123rf.com)... 108.138.85.106, 108.138.85.113, 108.138.85.32, ...
# Connecting to previews.123rf.com (previews.123rf.com)|108.138.85.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132329 (129K) [image/jpeg]
# Saving to: ‘p21.jpg’
#
# p21.jpg             100%[===================>] 129.23K  --.-KB/s    in 0.003s
#
# 2023-12-09 08:27:16 (41.4 MB/s) - ‘p21.jpg’ saved [132329/132329]
